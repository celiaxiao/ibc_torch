# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from trajectory_dataset import Simple_trajectory_dataset
import matplotlib.pyplot as plt
import numpy as np
dataset = torch.load('./trajectory/multi_line_dense.pt')
experences = dataset.experiences

# %%
for i in range(len(experences)):
    # if i > 10:
    #     break
    exp = experences[i]
    obs = exp['observation']['state'].cpu()
    act = exp['action'].cpu()
    traj = np.vstack((obs,(obs+act)))
    plt.plot(traj[:,0], traj[:,1])
plt.show()

# %%
import policy_eval
policy_eval.evaluate(5, 'PARTICLE', False, False, False, 
    static_policy='particle_green_then_blue', viz_img=True)
# Out:
# /home/caiwei/anaconda3/envs/py36/lib/python3.6/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# static_policy == particle_green_then_blue <tf_agents.environments.gym_wrapper.GymWrapper object at 0x7f6a54d71a90>
# MLPEBM(
#   (_mlp): ResNetLayer(
#     (_projection_layer): Linear(in_features=10, out_features=512, bias=True)
#     (identity): Identity()
#     (_weight_layers): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): Linear(in_features=512, out_features=512, bias=True)
#     )
#     (_norm_layers): ModuleList()
#     (_activation_layers): ModuleList(
#       (0): ReLU()
#       (1): ReLU()
#     )
#     (_dropouts): ModuleList(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#   )
# ...
